# %% [markdown]
# # 📈 Stock Price Time Series Analysis
# ### Power BI Dashboard + Python Visualization
# #### Vishakha Rao | Data Analyst Intern

# %% [markdown]
# This project analyzes historical stock prices with a focus on Apple Inc. It includes time series visualization using Python and a Power BI dashboard to explore trends, moving averages, and trading volumes. The goal is to demonstrate time series analysis and storytelling through data.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("stock_prices.csv", low_memory=False)

# Preview the first few rows and column names
print(df.head())
print(df.columns)
# Out:
#   symbol        date      open      high       low     close    volume
# 0    AAL  2014-01-02   25.0700   25.8200   25.0600   25.3600   8998943
# 1   AAPL  2014-01-02   79.3828   79.5756   78.8601   79.0185  58791957
# 2    AAP  2014-01-02  110.3600  111.8800  109.2900  109.7400    542711
# 3   ABBV  2014-01-02   52.1200   52.3300   51.5200   51.9800   4569061
# 4    ABC  2014-01-02   70.1100   70.2300   69.4800   69.8900   1148391
# Index(['symbol', 'date', 'open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
# Filter for Apple stock
apple_df = df[df["symbol"] == "AAPL"]

# Sort by date
apple_df = apple_df.sort_values("date")

# Preview
print(apple_df.head())
# Out:
#      symbol        date     open     high      low    close     volume
# 1      AAPL  2014-01-02  79.3828  79.5756  78.8601  79.0185   58791957
# 484    AAPL  2014-01-03  78.9799  79.0999  77.2042  77.2828   98303870
# 967    AAPL  2014-01-06  76.7785  78.1142  76.2285  77.7042  103359151
# 1450   AAPL  2014-01-07  77.7599  77.9942  76.8464  77.1481   79432766
# 1933   AAPL  2014-01-08  76.9728  77.9371  76.9556  77.6371   64686685

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(apple_df["date"], apple_df["close"], label="Close Price")
plt.title("Apple Stock Price Over Time")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate 7-day and 30-day moving averages
apple_df["MA_7"] = apple_df["close"].rolling(window=7).mean()
apple_df["MA_30"] = apple_df["close"].rolling(window=30).mean()

# Plot closing price with moving averages
import matplotlib.pyplot as plt

plt.figure(figsize=(14,7))
plt.plot(apple_df["date"], apple_df["close"], label="Close Price", color="blue")
plt.plot(apple_df["date"], apple_df["MA_7"], label="7-Day MA", color="orange")
plt.plot(apple_df["date"], apple_df["MA_30"], label="30-Day MA", color="green")
plt.title("Apple Stock Price with Moving Averages")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 📊 Insights from Apple Stock Analysis
#
# - The 7-day moving average captures short-term fluctuations, useful for active traders.
# - The 30-day moving average smooths out noise and reveals long-term trends.
# - Apple’s stock shows a steady upward trend post-Q1 earnings, with occasional dips in volume.
# - These patterns can inform buy/sell decisions and risk management strategies.

# %% [markdown]
# ### 📊 Power BI Dashboard Overview
# ![Stock Performance Dashboard – Vishakha Rao](Stock_Performance_Dashboard_VishakhaRao_2025.png)

# %% [markdown]
# This dashboard visualizes stock trends, volume surges, and top performers using Power BI. It complements the time series analysis performed in Python and showcases business-ready insights.

# %% [markdown]
# ### ✅ Project Summary
# This notebook combines Python-based time series analysis with a Power BI dashboard to explore stock performance across major companies. It includes trend analysis, moving averages, and interactive visual storytelling.
